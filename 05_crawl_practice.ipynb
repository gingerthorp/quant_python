# %% [markdown]
# # 5.1 한국거래소의 산업별 현황 및 개별지표 크롤링

# %% [markdown]
# ## 5.1.1 업종분류 현황 크롤링
#
# - 먼저 코스피

# %%
import requests as rq
from io import BytesIO
import pandas as pd

# %%
gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'

gen_otp_data = {
  'mktId': 'STK',
  'trdDd': '20210108',
  'money': '1',
  'csvxls_isNo': 'false',
  'name': 'fileDown',
  'url': 'dbms/MDC/STAT/standard/MDCSTAT03901'
}

headers = {'User-Agent': 'Chrome/78.0.3904.87 Safari/537.36',
           'Referer': 'http://data.krx.co.kr/contents/MDC/MDI/mdiLoader',
           'Upgrade-Insecure-Requests': '1'}

otp = rq.post(gen_otp_url, gen_otp_data, headers=headers).text

# %%
otp
# Out:
# 'qJTghdjG1a9lmcR/S8dMKGzSYNAWtBpLZyOKSKq6rBURtSksuLS7Bnxpl86F7dAOkunw9BBwugQaSjGAcH15eaZ8NA5R6MzhK2oIoU32nFwtBgM+EFJCxYg3zco1gIgRZqIo4cIzoURnTI8+MmkJ4m8vFLhSKmM794gFu+ThsO31lY4woqehX8j6OlXFDcfHdV4NbYo4+D2Rwcfj24VnU3Zpq3ik/Dyw3FdyOXhJkBI='

# %%
down_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
down_sector_KS  = rq.post(down_url, {'code':otp}, headers=headers)

sector_KS = pd.read_csv(BytesIO(down_sector_KS.content), encoding='EUC-KR')

# %%
sector_KS
# Out:
#        종목코드      종목명   시장구분    업종명      종가    대비   등락률           시가총액
# 0    095570   AJ네트웍스  KOSPI   서비스업    4540  -155 -3.30   212573219300
# 1    006840    AK홀딩스  KOSPI   기타금융   25350   150  0.60   335825671350
# 2    027410      BGF  KOSPI   기타금융    4905   -25 -0.51   469490859855
# 3    282330   BGF리테일  KOSPI    유통업  141000  4500  3.30  2437030746000
# 4    138930  BNK금융지주  KOSPI   기타금융    5780     0  0.00  1883905721880
# ..      ...      ...    ...    ...     ...   ...   ...            ...
# 912  069260      휴켐스  KOSPI     화학   26000  -100 -0.38  1062843288000
# 913  000540     흥국화재  KOSPI     보험    3000     5  0.17   192727935000
# 914  000547  흥국화재2우B  KOSPI     보험   19950   -50 -0.25     3064320000
# 915  000545    흥국화재우  KOSPI     보험    7660  -240 -3.04     5882880000
# 916  003280     흥아해운  KOSPI  운수창고업     258     0  0.00    30117000222
#
# [917 rows x 8 columns]

# %% [markdown]
# - 코스닥

# %%
gen_otp_data = {
  'mktId': 'KSQ',
  'trdDd': '20210108',
  'money': '1',
  'csvxls_isNo': 'false',
  'name': 'fileDown',
  'url': 'dbms/MDC/STAT/standard/MDCSTAT03901'
}

otp = rq.post(gen_otp_url, gen_otp_data, headers=headers).text         

down_sector_KQ  = rq.post(down_url, {'code':otp}, headers=headers)
sector_KQ = pd.read_csv(BytesIO(down_sector_KQ.content), encoding='EUC-KR')

# %%
sector_KQ
# Out:
#         종목코드     종목명    시장구분     업종명      종가    대비   등락률           시가총액
# 0     060310      3S  KOSDAQ   기계·장비    2245   -45 -1.97   100581637195
# 1     054620  APS홀딩스  KOSDAQ      금융    7500  -150 -1.96   152956657500
# 2     265520   AP시스템  KOSDAQ     반도체   26000  -100 -0.38   376485902000
# 3     211270    AP위성  KOSDAQ    통신장비    8100  -250 -2.99   121619912400
# 4     035760  CJ ENM  KOSDAQ   방송서비스  156200  8500  5.75  3425333854800
# ...      ...     ...     ...     ...     ...   ...   ...            ...
# 1466  024060    흥구석유  KOSDAQ      유통    7510   -40 -0.53   112650000000
# 1467  010240      흥국  KOSDAQ   기계·장비    5910     0  0.00    72827133360
# 1468  189980  흥국에프엔비  KOSDAQ  음식료·담배    2010   -40 -1.95    77158125270
# 1469  037440      희림  KOSDAQ   기타서비스    3935   -15 -0.38    54784939125
# 1470  238490      힘스  KOSDAQ     반도체   12950  -150 -1.15   146493456200
#
# [1471 rows x 8 columns]

# %%
down_sector = pd.concat([sector_KS, sector_KQ]).reset_index(drop=True)
down_sector['종목명'] = down_sector['종목명'].str.strip()

# %%
down_sector
# Out:
#         종목코드      종목명    시장구분     업종명      종가    대비   등락률           시가총액
# 0     095570   AJ네트웍스   KOSPI    서비스업    4540  -155 -3.30   212573219300
# 1     006840    AK홀딩스   KOSPI    기타금융   25350   150  0.60   335825671350
# 2     027410      BGF   KOSPI    기타금융    4905   -25 -0.51   469490859855
# 3     282330   BGF리테일   KOSPI     유통업  141000  4500  3.30  2437030746000
# 4     138930  BNK금융지주   KOSPI    기타금융    5780     0  0.00  1883905721880
# ...      ...      ...     ...     ...     ...   ...   ...            ...
# 2383  024060     흥구석유  KOSDAQ      유통    7510   -40 -0.53   112650000000
# 2384  010240       흥국  KOSDAQ   기계·장비    5910     0  0.00    72827133360
# 2385  189980   흥국에프엔비  KOSDAQ  음식료·담배    2010   -40 -1.95    77158125270
# 2386  037440       희림  KOSDAQ   기타서비스    3935   -15 -0.38    54784939125
# 2387  238490       힘스  KOSDAQ     반도체   12950  -150 -1.15   146493456200
#
# [2388 rows x 8 columns]

# %%
import os
if not os.path.exists('data'):
    os.makedirs('data')

down_sector.to_csv('data/krx_sector.csv')

# %% [markdown]
# ## 5.1.2 개별종목 지표 크롤링

# %%
import requests as rq
from io import BytesIO
import pandas as pd

gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'

gen_otp_data = {
  'searchType' : '1',
  'mktId' : 'ALL',
  'trdDd' : '20210108',
  'csvxls_isNo' : 'false',
  'name' : 'fileDown',
  'url' : 'dbms/MDC/STAT/standard/MDCSTAT03501'
}

headers = {'User-Agent': 'Chrome/78.0.3904.87 Safari/537.36',
           'Referer': 'http://data.krx.co.kr/contents/MDC/MDI/mdiLoader',
           'Upgrade-Insecure-Requests': '1'}

otp = rq.post(gen_otp_url, gen_otp_data, headers=headers).text         

down_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
down_ind  = rq.post(down_url, {'code':otp}, headers=headers)

down_ind = pd.read_csv(BytesIO(down_ind.content), encoding='EUC-KR')
down_ind['종목명'] = down_ind['종목명'].str.strip()

# %%
down_ind.to_csv('data/krx_ind.csv')

# %% [markdown]
# ## 5.1.3 최근 영업일 기준 데이터 받기
#
# - https://finance.naver.com/sise/sise_deposit.nhn

# %%
import requests as rq
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/sise/sise_deposit.nhn'

# %%
data = rq.get(url).content
data_html = BeautifulSoup(data, "html5lib")

# %%
parse_day = data_html.select_one('.tah').text

# %%
print(parse_day)
# Out:
#   |  2021.02.03

# %%
import re
biz_day = re.findall("[0-9]+", parse_day)
biz_day = "".join(biz_day)

print(biz_day)
# Out:
# 20210203

# %% [markdown]
# - 영업일 기준 거래소 데이터 다운로드

# %%
import requests as rq
from bs4 import BeautifulSoup
import re
import requests as rq
from io import BytesIO
import pandas as pd
import os

if not os.path.exists('data'):
    os.makedirs('data')

# 최근 영업일 구하기
url = 'https://finance.naver.com/sise/sise_deposit.nhn'
data = rq.get(url).content
data_html = BeautifulSoup(data, "html5lib")
parse_day = data_html.select_one('.tah').text
biz_day = re.findall("[0-9]+", parse_day)
biz_day = "".join(biz_day)

# 코스피 업종분류 데이터 다운로드
gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'

gen_otp_data = {
  'mktId': 'STK',
  'trdDd': '20210108',
  'money': '1',
  'csvxls_isNo': 'false',
  'name': 'fileDown',
  'url': 'dbms/MDC/STAT/standard/MDCSTAT03901'
}

headers = {'User-Agent': 'Chrome/78.0.3904.87 Safari/537.36',
           'Referer': 'http://data.krx.co.kr/contents/MDC/MDI/mdiLoader',
           'Upgrade-Insecure-Requests': '1'}

otp = rq.post(gen_otp_url, gen_otp_data, headers=headers).text   

down_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
down_sector_KS  = rq.post(down_url, {'code':otp}, headers=headers)

sector_KS = pd.read_csv(BytesIO(down_sector_KS.content), encoding='EUC-KR')

# 코스닥 업종분류 데이터 다운로드
gen_otp_data = {
  'mktId': 'KSQ',
  'trdDd': '20210108',
  'money': '1',
  'csvxls_isNo': 'false',
  'name': 'fileDown',
  'url': 'dbms/MDC/STAT/standard/MDCSTAT03901'
}

otp = rq.post(gen_otp_url, gen_otp_data, headers=headers).text         

down_sector_KQ  = rq.post(down_url, {'code':otp}, headers=headers)
sector_KQ = pd.read_csv(BytesIO(down_sector_KQ.content), encoding='EUC-KR')

# 합치기
down_sector = pd.concat([sector_KS, sector_KQ]).reset_index(drop=True)
down_sector['종목명'] = down_sector['종목명'].str.strip()
down_sector.to_csv('data/krx_sector.csv')

# 개별종목 지표 OTP 발급
gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'

gen_otp_data = {
  'searchType' : '1',
  'mktId' : 'ALL',
  'trdDd' : '20210108',
  'csvxls_isNo' : 'false',
  'name' : 'fileDown',
  'url' : 'dbms/MDC/STAT/standard/MDCSTAT03501'
}

otp = rq.post(gen_otp_url, gen_otp_data, headers=headers).text         

down_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
down_ind  = rq.post(down_url, {'code':otp}, headers=headers)

down_ind = pd.read_csv(BytesIO(down_ind.content), encoding='EUC-KR')
down_ind['종목명'] = down_ind['종목명'].str.strip()
down_ind.to_csv('data/krx_ind.csv')

# %% [markdown]
# ## 5.1.4 거래소 데이터 정리하기

# %%
down_sector = pd.read_csv('data/krx_sector.csv', index_col = 0)
down_ind = pd.read_csv('data/krx_ind.csv', index_col = 0)

# %%
down_sector.columns & down_ind.columns
# Out:
# Index(['종목코드', '종목명', '종가', '대비', '등락률'], dtype='object')

# %%
set(down_sector['종목명']).symmetric_difference(down_ind['종목명'])
# Out:
# {'ESR켄달스퀘어리츠',
#  'GRT',
#  'JTC',
#  'NH프라임리츠',
#  'SBI핀테크솔루션즈',
#  'SNK',
#  '골든센츄리',
#  '글로벌에스엠',
#  '뉴프라이드',
#  '로스웰',
#  '롯데리츠',
#  '맥쿼리인프라',
#  '맵스리얼티1',
#  '모두투어리츠',
#  '미래에셋맵스리츠',
#  '미투젠',
#  '바다로19호',
#  '베트남개발1',
#  '소마젠(Reg.S)',
#  '신한알파리츠',
#  '씨케이에이치',
#  '에스앤씨엔진그룹',
#  '에이리츠',
#  '엑세스바이오',
#  '엘브이엠씨홀딩스',
#  '오가닉티코스메틱',
#  '윙입푸드',
#  '이리츠코크렙',
#  '이스트아시아홀딩스',
#  '이지스레지던스리츠',
#  '이지스밸류리츠',
#  '잉글우드랩',
#  '제이알글로벌리츠',
#  '컬러레이',
#  '케이탑리츠',
#  '코람코에너지리츠',
#  '코오롱티슈진',
#  '크리스탈신소재',
#  '하이골드12호',
#  '하이골드3호',
#  '한국ANKOR유전',
#  '한국패러랠',
#  '헝셩그룹'}

# %%
down_sector.columns & down_ind.columns
# Out:
# Index(['종목코드', '종목명', '종가', '대비', '등락률'], dtype='object')

# %%
KOR_ticker = pd.merge(down_sector, down_ind, on = (down_sector.columns & down_ind.columns).tolist(), how = 'inner')
KOR_ticker = KOR_ticker.sort_values(by = ['시가총액'], ascending = False)

# %%
KOR_ticker
# Out:
#        종목코드       종목명   시장구분    업종명      종가     대비   등락률             시가총액  \
# 401  005930      삼성전자  KOSPI   전기전자   88800   5900  7.12  530116690440000
# 132  000660    SK하이닉스  KOSPI   전기전자  138000   3500  2.60  100464326370000
# 81   051910      LG화학  KOSPI     화학  999000  37000  3.85   70521750657000
# 402  005935     삼성전자우  KOSPI   전기전자   77800   3500  4.71   64020585260000
# 395  207940  삼성바이오로직스  KOSPI    의약품  837000  18000  2.20   55380105000000
# ..      ...       ...    ...    ...     ...    ...   ...              ...
# 665  002787   진흥기업2우B  KOSPI    건설업   12100   -250 -2.02       3567176800
# 500  009275       신원우  KOSPI   섬유의복   38350   -650 -1.67       3479879000
# 204  000325    노루홀딩스우  KOSPI   기타금융   17550   -200 -1.13       3251137500
# 892  000547   흥국화재2우B  KOSPI     보험   19950    -50 -0.25       3064320000
# 288  001529     동양3우B  KOSPI  비금속광물   30050    250  0.84       2696146100
#
#         EPS     PER       BPS    PBR  주당배당금  배당수익률
# 401  3166.0   28.05   37528.0   2.37   1416   1.59
# 132  2943.0   46.89   65836.0   2.10   1000   0.72
# 81   4085.0  244.55  217230.0   4.60   2000   0.20
# 402     NaN     NaN       NaN    NaN   1417   1.82
# 395  3067.0  272.91   65812.0  12.72      0   0.00
# ..      ...     ...       ...    ...    ...    ...
# 665     NaN     NaN       NaN    NaN      0   0.00
# 500     NaN     NaN       NaN    NaN      0   0.00
# 204     NaN     NaN       NaN    NaN    405   2.31
# 892     NaN     NaN       NaN    NaN      0   0.00
# 288     NaN     NaN       NaN    NaN    150   0.50
#
# [2345 rows x 14 columns]

# %%
KOR_ticker[KOR_ticker['종목명'].str.contains('스팩')]['종목명']
# Out:
# 1693      엔에이치스팩14호
# 1006         교보8호스팩
# 1844       유안타제3호스팩
# 2044      케이비제18호스팩
# 1360         삼성스팩2호
# 1695      엔에이치스팩17호
# 1847       유안타제6호스팩
# 1283     미래에셋대우스팩3호
# 2046      케이비제20호스팩
# 905        DB금융스팩8호
# 1846       유안타제5호스팩
# 1103     대신밸런스제8호스팩
# 963          SK6호스팩
# 2043       케이비17호스팩
# 1848       유안타제7호스팩
# 1102     대신밸런스제7호스팩
# 1005        교보10호스팩
# 2306      한화에스비아이스팩
# 918      IBKS제13호스팩
# 1282    미래에셋대우스팩 5호
# 2256        하이제5호스팩
# 961          SK4호스팩
# 2276        한국제7호스팩
# 1656     에이치엠씨제5호스팩
# 1491        신한제6호스팩
# 2244      하나금융15호스팩
# 2248     하나머스트제6호스팩
# 1845       유안타제4호스팩
# 1377      상상인이안1호스팩
# 2307     한화플러스제1호스팩
# 1696      엔에이치스팩18호
# 919      IBKS제14호스팩
# 2243      하나금융14호스팩
# 1284     미래에셋대우스팩4호
# 1694      엔에이치스팩16호
# 962          SK5호스팩
# 2045      케이비제19호스팩
# 1486         신영스팩6호
# 1104     대신밸런스제9호스팩
# 1655     에이치엠씨제4호스팩
# 2245      하나금융16호스팩
# 1854         유진스팩5호
# 1007         교보9호스팩
# 1692      엔에이치스팩13호
# 1378     상상인이안제2호스팩
# 2125        키움제5호스팩
# 1882       이베스트스팩5호
# 1485         신영스팩5호
# 1853         유진스팩4호
# 2277        한국제8호스팩
# 917      IBKS제12호스팩
# 1883     이베스트이안스팩1호
# Name: 종목명, dtype: object

# %%
KOR_ticker[KOR_ticker['종목코드'].str[-1:] != '0']['종목명']
# Out:
# 402      삼성전자우
# 856     현대차2우B
# 82       LG화학우
# 858       현대차우
# 72     LG생활건강우
#         ...
# 665    진흥기업2우B
# 500        신원우
# 204     노루홀딩스우
# 892    흥국화재2우B
# 288      동양3우B
# Name: 종목명, Length: 120, dtype: object

# %%
KOR_ticker = KOR_ticker[~KOR_ticker['종목명'].str.contains('스팩')]
KOR_ticker = KOR_ticker[KOR_ticker['종목코드'].str[-1:] == '0']
KOR_ticker = KOR_ticker.reset_index(drop=True)

# %%
KOR_ticker
# Out:
#         종목코드        종목명    시장구분    업종명      종가     대비    등락률             시가총액  \
# 0     005930       삼성전자   KOSPI   전기전자   88800   5900   7.12  530116690440000
# 1     000660     SK하이닉스   KOSPI   전기전자  138000   3500   2.60  100464326370000
# 2     051910       LG화학   KOSPI     화학  999000  37000   3.85   70521750657000
# 3     207940   삼성바이오로직스   KOSPI    의약품  837000  18000   2.20   55380105000000
# 4     005380        현대차   KOSPI   운수장비  246000  40000  19.42   52562374002000
# ...      ...        ...     ...    ...     ...    ...    ...              ...
# 2168  114570    지스마트글로벌  KOSDAQ    반도체     620      0   0.00       7030424280
# 2169  080440     에스제이케이  KOSDAQ     유통     498      0   0.00       6636328080
# 2170  058420       제이웨이  KOSDAQ  오락·문화     289    -28  -8.83       6264626701
# 2171  347140  케이프이에스제4호  KOSDAQ     금융    2050      0   0.00       6168450000
# 2172  158310     스타모빌리티  KOSDAQ  기계·장비     505      0   0.00       6096179210
#
#           EPS     PER       BPS    PBR  주당배당금  배당수익률
# 0      3166.0   28.05   37528.0   2.37   1416   1.59
# 1      2943.0   46.89   65836.0   2.10   1000   0.72
# 2      4085.0  244.55  217230.0   4.60   2000   0.20
# 3      3067.0  272.91   65812.0  12.72      0   0.00
# 4     11310.0   21.75  253001.0   0.97   4000   1.63
# ...       ...     ...       ...    ...    ...    ...
# 2168      NaN     NaN    4180.0   0.15      0   0.00
# 2169      NaN     NaN     997.0   0.50      0   0.00
# 2170      NaN     NaN     578.0   0.50      0   0.00
# 2171      NaN     NaN       NaN    NaN      0   0.00
# 2172      NaN     NaN    2426.0   0.21      0   0.00
#
# [2173 rows x 14 columns]

# %%
KOR_ticker.to_csv('data/KOR_ticker.csv')

# %% [markdown]
# # 5.2 WICS 기준 섹터정보 크롤링

# %%
import json
import requests as rq

# %%
url = 'http://www.wiseindex.com/Index/GetIndexComponets?ceil_yn=0&dt=20190607&sec_cd=G10'
data = rq.get(url).json()

# %%
data_pd = pd.json_normalize(data['list'])
data_pd
# Out:
#    IDX_CD IDX_NM_KOR  ALL_MKT_VAL  CMP_CD    CMP_KOR  MKT_VAL    WGT   S_WGT  \
# 0     G10   WICS 에너지     19850082  096770    SK이노베이션  9052841  45.61   45.61
# 1     G10   WICS 에너지     19850082  010950      S-Oil  3403265  17.14   62.75
# 2     G10   WICS 에너지     19850082  267250    현대중공업지주  2873204  14.47   77.23
# 3     G10   WICS 에너지     19850082  078930         GS  2491805  12.55   89.78
# 4     G10   WICS 에너지     19850082  067630  에이치엘비생명과학   624986   3.15   92.93
# 5     G10   WICS 에너지     19850082  006120    SK디스커버리   257059   1.30   94.22
# 6     G10   WICS 에너지     19850082  002960      한국쉘석유   198881   1.00   95.22
# 7     G10   WICS 에너지     19850082  091090      세원셀론텍   146439   0.74   95.96
# 8     G10   WICS 에너지     19850082  011930      신성이엔지   118388   0.60   96.56
# 9     G10   WICS 에너지     19850082  128820       대성산업    79162   0.40   96.96
# 10    G10   WICS 에너지     19850082  043200         파루    75903   0.38   97.34
# 11    G10   WICS 에너지     19850082  003650       미창석유    71918   0.36   97.70
# 12    G10   WICS 에너지     19850082  014530       극동유화    62828   0.32   98.02
# 13    G10   WICS 에너지     19850082  099220        SDN    55967   0.28   98.30
# 14    G10   WICS 에너지     19850082  024060       흥구석유    53460   0.27   98.57
# 15    G10   WICS 에너지     19850082  041590      젬백스지오    50901   0.26   98.83
# 16    G10   WICS 에너지     19850082  095910      에스에너지    46873   0.24   99.06
# 17    G10   WICS 에너지     19850082  060900     대한그린파워    43739   0.22   99.28
# 18    G10   WICS 에너지     19850082  012320     경동인베스트    40030   0.20   99.48
# 19    G10   WICS 에너지     19850082  093230       이아이디    32266   0.16   99.65
# 20    G10   WICS 에너지     19850082  038620       위즈코프    30094   0.15   99.80
# 21    G10   WICS 에너지     19850082  137950     제이씨케미칼    29363   0.15   99.95
# 22    G10   WICS 에너지     19850082  000440     중앙에너비스    10711   0.05  100.00
#
#     CAL_WGT SEC_CD SEC_NM_KOR  SEQ  TOP60  APT_SHR_CNT
# 0       1.0    G10        에너지    1      2     56403994
# 1       1.0    G10        에너지    2      2     41655633
# 2       1.0    G10        에너지    3      2      9283372
# 3       1.0    G10        에너지    4      2     49245150
# 4       1.0    G10        에너지    5      2     39307272
# 5       1.0    G10        에너지    6      2     10470820
# 6       1.0    G10        에너지    7      2       611000
# 7       1.0    G10        에너지    8      2     42693554
# 8       1.0    G10        에너지    9      2    100756131
# 9       1.0    G10        에너지   10      2     15832417
# 10      1.0    G10        에너지   11      2     29707590
# 11      1.0    G10        에너지   12      2       922026
# 12      1.0    G10        에너지   13      2     18132098
# 13      1.0    G10        에너지   14      2     38598075
# 14      1.0    G10        에너지   15      2      9000000
# 15      1.0    G10        에너지   16      2     31132353
# 16      1.0    G10        에너지   17      2     10290527
# 17      1.0    G10        에너지   18      2     53017111
# 18      1.0    G10        에너지   19      2       993310
# 19      1.0    G10        에너지   20      2    140285009
# 20      1.0    G10        에너지   21      2     24075079
# 21      1.0    G10        에너지   22      2      8353752
# 22      1.0    G10        에너지   23      2      1556783

# %%
import time
import json
import requests as rq
import pandas as pd

sector_code = ['G25', 'G35', 'G50', 'G40', 'G10', 'G20', 'G55', 'G30', 'G15', 'G45']

data_sector = {}

for i in sector_code:
  url = 'http://www.wiseindex.com/Index/GetIndexComponets?ceil_yn=0&dt='+biz_day+'&sec_cd='+i
  data = rq.get(url).json()
  data_pd = pd.json_normalize(data['list'])

  data_sector[i] = data_pd

  time.sleep(2)

# %%
sector_list = [v for k,v in data_sector.items()] 
KOR_sector = pd.concat(sector_list).reset_index(drop=True)

# %%
KOR_sector
# Out:
#      IDX_CD    IDX_NM_KOR  ALL_MKT_VAL  CMP_CD CMP_KOR   MKT_VAL    WGT  \
# 0       G25  WICS 경기관련소비재    175164933  005380     현대차  34620656  19.76
# 1       G25  WICS 경기관련소비재    175164933  000270     기아차  24554479  14.02
# 2       G25  WICS 경기관련소비재    175164933  012330   현대모비스  22131109  12.63
# 3       G25  WICS 경기관련소비재    175164933  051900  LG생활건강  15293339   8.73
# 4       G25  WICS 경기관련소비재    175164933  090430  아모레퍼시픽   6915639   3.95
# ...     ...           ...          ...     ...     ...       ...    ...
# 2138    G45       WICS IT    627871417  043360    디지아이     12497   0.00
# 2139    G45       WICS IT    627871417  032960    동일기연     12305   0.00
# 2140    G45       WICS IT    627871417  115610    이미지스     12186   0.00
# 2141    G45       WICS IT    627871417  191410  육일씨엔에쓰     12153   0.00
# 2142    G45       WICS IT    627871417  004920   씨아이테크     11587   0.00
#
#        S_WGT  CAL_WGT SEC_CD SEC_NM_KOR  SEQ  TOP60  APT_SHR_CNT
# 0      19.76      1.0    G25    경기관련소비재    1      6    141021003
# 1      33.78      1.0    G25    경기관련소비재    2      6    251325275
# 2      46.42      1.0    G25    경기관련소비재    3      6     63686645
# 3      55.15      1.0    G25    경기관련소비재    4      6      9370918
# 4      59.10      1.0    G25    경기관련소비재    5      6     30398415
# ...      ...      ...    ...        ...  ...    ...          ...
# 2138   99.99      1.0    G45         IT  555      0      4770000
# 2139   99.99      1.0    G45         IT  556      0       875821
# 2140  100.00      1.0    G45         IT  557      0      5368390
# 2141  100.00      1.0    G45         IT  558      0      4775141
# 2142  100.00      1.0    G45         IT  559      0     13287509
#
# [2143 rows x 14 columns]

# %%
KOR_sector.to_csv('data/KOR_sector.csv')
